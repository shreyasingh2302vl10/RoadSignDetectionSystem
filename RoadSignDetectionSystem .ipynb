# %% [markdown]
# # Access/Enable GP for fast processing

# %%
import os
if 'COLAB_GPU' in os.environ:
  print("GPU is enabled!")
else :
  print("GPU is enabled")
# Out:
# GPU is enabled!

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.1 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.5/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content'

# %%
# !ls RoadSignDetection

# %%
path="/content/RoadSignDetection"

# %%
# %pwd
# Out:
# '/content'

# %%
os.chdir("/content/RoadSignDetection")
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir RoadSignDetection

# %%
# !ls
# Out:
# RoadSignDetection  Self-Driving-Cars-6

# %%
path="/content/RoadSignDetection"

# %%
# %pwd
# Out:
# '/content'

# %%
import os

# %%
os.chdir("/content/RoadSignDetection")
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6gpctWjpfGPD6gG49skw")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:01<00:00, 6757.83it/s]

# %%
# !rm -rf Self-Driving-Cars-6

# %%
# !rm -rf Self-Driving-Cars-6

# %%
# !rm -rf /content//content/Self-Driving-Cars-6

# %%
/content/Self-Driving-Cars-6
# Out:
# 'int' object is not callable; perhaps you missed a comma?
# 'int' object is not callable; perhaps you missed a comma?
# 'int' object is not callable; perhaps you missed a comma?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_469/3965707186.py in <cell line: 0>()
# ----> 1 content/Self-Driving-Cars-6()
#
# NameError: name 'content' is not defined

# %%
# !rm -rf /content/Self-Driving-Cars-6

# %%
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6gpctWjpfGPD6gG49skw")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-6 in yolov8:: 100%|██████████| 9950/9950 [00:00<00:00, 10123.34it/s]

# %% [markdown]
# # Train the YOLOv8 over the custom Dataset

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yml epochs=10 imgsz=640 batch=16
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 62.5 MB/s eta 0:00:00
# ...

# %%
os.chdir("/content/RoadSignDetection/Self-Driving-Cars-6")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/RoadSignDetection/Self-Driving-Cars-6/data.yaml epochs=10 imgsz=640 batch=16
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# # Display Some of the content we obtained

# %%
# !ls '/content/RoadSignDetection/runs/detect/train4/'
# Out:
# args.yaml			 labels.jpg		val_batch0_pred.jpg
# BoxF1_curve.png			 results.csv		val_batch1_labels.jpg
# BoxP_curve.png			 results.png		val_batch1_pred.jpg
# BoxPR_curve.png			 train_batch0.jpg	val_batch2_labels.jpg
# BoxR_curve.png			 train_batch1.jpg	val_batch2_pred.jpg
# confusion_matrix_normalized.png  train_batch2.jpg	weights
# confusion_matrix.png		 val_batch0_labels.jpg

# %%
resultData="/content/RoadSignDetection/runs/detect/train4/"
from IPython.display import Image,display
Image(filename= f'{resultData}confusion_matrix.png')

# %%
Image(filename= f'{resultData}results.png')

# %%
import pandas as pd
df=pd.read_csv(f'{resultData}results.csv')
print(df.head(5))
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   74.4955         0.88438         4.05192         1.20680
# 1      2  142.4040         0.78186         2.94442         1.07037
# 2      3  209.2070         0.75340         2.24902         1.04956
# 3      4  276.2490         0.72042         1.77266         1.02456
# 4      5  342.7870         0.68384         1.39673         0.99965
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.32390            0.45445           0.31522
# 1               0.49982            0.58801           0.58125
# 2               0.70397            0.58490           0.66497
# 3               0.73462            0.73035           0.79629
# 4               0.84483            0.75621           0.84650
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.24950       0.82658       1.98106       1.12681  0.000175
# ...

# %%
import pandas as pd
df=pd.read_csv(f'{resultData}results.csv')
print(df.tail(1))
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 9     10  678.425         0.56763         0.74431          0.9352
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 9               0.94755            0.84215           0.93544
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 9               0.8005       0.60588       0.52516       0.96017  0.000057
#
#      lr/pg1    lr/pg2
# 9  0.000057  0.000057

# %% [markdown]
# # Test your model on any arbitary video containing road signs

# %%
# %pwd
# Out:
# '/content/RoadSignDetection/Self-Driving-Cars-6'

# %%
os.chdir("/content")

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir ManualTestingData

# %%
weightsPath="/content/RoadSignDetection/runs/detect/train4/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=0.25 source='/content/ManualTestingData/traffic_light.png'
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/ManualTestingData/traffic_light.png: 512x640 5 Red Lights, 82.8ms
# Speed: 4.1ms preprocess, 82.8ms inference, 23.3ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
weightsPath="/content/RoadSignDetection/runs/detect/train4/weights"
# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=0.25 source='/content/ManualTestingData/traffic_light.png'
# Out:
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,008,573 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/ManualTestingData/traffic_light.png: 512x640 5 Red Lights, 68.4ms
# Speed: 4.6ms preprocess, 68.4ms inference, 23.3ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
